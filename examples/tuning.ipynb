# %% [markdown]
# ## Tuning of XGBoost estimator

# %%
from pinard import nirs_set as n_set
from sklearn.model_selection import train_test_split
import numpy as np

# Init basic random
rd_seed = 42
np.random.seed(rd_seed)

# Create a set named data
n = n_set.NIRS_Set('data')

# Load csv data and split into train and test
X, y = n.load('Xcal.csv', 'Ycal.csv', x_hdr=0, y_hdr=0, y_cols=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = rd_seed)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)

from pinard import preprocessor as pp
from sklearn.pipeline import Pipeline

### Declare preprocessing pipeline components
preprocessing = [   ('id', pp.IdentityTransformer()),
                    ('savgol', pp.SavitzkyGolay()),
                    ('gaussian1', pp.Gaussian(order = 1, sigma = 2)),
                    ('gaussian2', pp.Gaussian(order = 2, sigma = 1)),
                    ('haar', pp.Wavelet('haar')),
                    ('savgol*savgol', Pipeline([('_sg1',pp.SavitzkyGolay()),('_sg2',pp.SavitzkyGolay())])),
                    ('gaussian1*savgol', Pipeline([('_g1',pp.Gaussian(order = 1, sigma = 2)),('_sg3',pp.SavitzkyGolay())])),
                    ('gaussian2*savgol', Pipeline([('_g2',pp.Gaussian(order = 1, sigma = 2)),('_sg4',pp.SavitzkyGolay())])),
                    ('haar*savgol', Pipeline([('_haar2',pp.Wavelet('haar')),('_sg5',pp.SavitzkyGolay())]))
                ]
# Out:
# (288, 2151) (288,) (73, 2151) (73,)

# %% [markdown]
# ## XGBoost model + params

# %%
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from xgboost import XGBRegressor

x_pipeline = Pipeline([
    ('scaler', MinMaxScaler()), 
    ('preprocessing', FeatureUnion(preprocessing)), 
    ('XGB', XGBRegressor())
])

x_estimator = TransformedTargetRegressor(regressor = x_pipeline, transformer = MinMaxScaler())

print(x_estimator.get_params())
# Out:
# {'check_inverse': True, 'func': None, 'inverse_func': None, 'regressor__memory': None, 'regressor__steps': [('scaler', MinMaxScaler()), ('preprocessing', FeatureUnion(transformer_list=[('id', FunctionTransformer()),
#                                ('savgol', SavitzkyGolay()),
#                                ('gaussian1', Gaussian(sigma=2)),
#                                ('gaussian2', Gaussian(order=2)),
#                                ('haar', Wavelet()),
#                                ('savgol*savgol',
#                                 Pipeline(steps=[('_sg1', SavitzkyGolay()),
#                                                 ('_sg2', SavitzkyGolay())])),
#                                ('gaussian1*savgol',
#                                 Pipeline(steps=[('_g1', Gaussian(sigma=2)),
#                                                 ('_sg3', SavitzkyGolay())])),
#                                ('gaussian2*savgol',
#                                 Pipeline(steps=[('_g2', Gaussian(sigma=2)),
#                                                 ('_sg4', SavitzkyGolay())])),
#                                ('haar*savgol',
#                                 Pipeline(steps=[('_haar2', Wavelet()),
#                                                 ('_sg5', SavitzkyGolay())]))])), ('XGB', XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None,
#              enable_categorical=False, gamma=None, gpu_id=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=None))], 'regressor__verbose': False, 'regressor__scaler': MinMaxScaler(), 'regressor__preprocessing': FeatureUnion(transformer_list=[('id', FunctionTransformer()),
#                                ('savgol', SavitzkyGolay()),
#                                ('gaussian1', Gaussian(sigma=2)),
#                                ('gaussian2', Gaussian(order=2)),
#                                ('haar', Wavelet()),
#                                ('savgol*savgol',
#                                 Pipeline(steps=[('_sg1', SavitzkyGolay()),
#                                                 ('_sg2', SavitzkyGolay())])),
#                                ('gaussian1*savgol',
#                                 Pipeline(steps=[('_g1', Gaussian(sigma=2)),
#                                                 ('_sg3', SavitzkyGolay())])),
#                                ('gaussian2*savgol',
#                                 Pipeline(steps=[('_g2', Gaussian(sigma=2)),
#                                                 ('_sg4', SavitzkyGolay())])),
#                                ('haar*savgol',
#                                 Pipeline(steps=[('_haar2', Wavelet()),
#                                                 ('_sg5', SavitzkyGolay())]))]), 'regressor__XGB': XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None,
#              enable_categorical=False, gamma=None, gpu_id=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=None), 'regressor__scaler__clip': False, 'regressor__scaler__copy': True, 'regressor__scaler__feature_range': (0, 1), 'regressor__preprocessing__n_jobs': None, 'regressor__preprocessing__transformer_list': [('id', FunctionTransformer()), ('savgol', SavitzkyGolay()), ('gaussian1', Gaussian(sigma=2)), ('gaussian2', Gaussian(order=2)), ('haar', Wavelet()), ('savgol*savgol', Pipeline(steps=[('_sg1', SavitzkyGolay()), ('_sg2', SavitzkyGolay())])), ('gaussian1*savgol', Pipeline(steps=[('_g1', Gaussian(sigma=2)), ('_sg3', SavitzkyGolay())])), ('gaussian2*savgol', Pipeline(steps=[('_g2', Gaussian(sigma=2)), ('_sg4', SavitzkyGolay())])), ('haar*savgol', Pipeline(steps=[('_haar2', Wavelet()), ('_sg5', SavitzkyGolay())]))], 'regressor__preprocessing__transformer_weights': None, 'regressor__preprocessing__verbose': False, 'regressor__preprocessing__id': FunctionTransformer(), 'regressor__preprocessing__savgol': SavitzkyGolay(), 'regressor__preprocessing__gaussian1': Gaussian(sigma=2), 'regressor__preprocessing__gaussian2': Gaussian(order=2), 'regressor__preprocessing__haar': Wavelet(), 'regressor__preprocessing__savgol*savgol': Pipeline(steps=[('_sg1', SavitzkyGolay()), ('_sg2', SavitzkyGolay())]), 'regressor__preprocessing__gaussian1*savgol': Pipeline(steps=[('_g1', Gaussian(sigma=2)), ('_sg3', SavitzkyGolay())]), 'regressor__preprocessing__gaussian2*savgol': Pipeline(steps=[('_g2', Gaussian(sigma=2)), ('_sg4', SavitzkyGolay())]), 'regressor__preprocessing__haar*savgol': Pipeline(steps=[('_haar2', Wavelet()), ('_sg5', SavitzkyGolay())]), 'regressor__preprocessing__id__accept_sparse': False, 'regressor__preprocessing__id__check_inverse': True, 'regressor__preprocessing__id__func': None, 'regressor__preprocessing__id__inv_kw_args': None, 'regressor__preprocessing__id__inverse_func': None, 'regressor__preprocessing__id__kw_args': None, 'regressor__preprocessing__id__validate': False, 'regressor__preprocessing__savgol__copy': True, 'regressor__preprocessing__savgol__delta': 1.0, 'regressor__preprocessing__savgol__deriv': 0, 'regressor__preprocessing__savgol__polyorder': 3, 'regressor__preprocessing__savgol__window_length': 11, 'regressor__preprocessing__gaussian1__copy': True, 'regressor__preprocessing__gaussian1__order': 1, 'regressor__preprocessing__gaussian1__sigma': 2, 'regressor__preprocessing__gaussian2__copy': True, 'regressor__preprocessing__gaussian2__order': 2, 'regressor__preprocessing__gaussian2__sigma': 1, 'regressor__preprocessing__haar__copy': True, 'regressor__preprocessing__haar__mode': 'per', 'regressor__preprocessing__haar__wavelet': 'haar', 'regressor__preprocessing__savgol*savgol__memory': None, 'regressor__preprocessing__savgol*savgol__steps': [('_sg1', SavitzkyGolay()), ('_sg2', SavitzkyGolay())], 'regressor__preprocessing__savgol*savgol__verbose': False, 'regressor__preprocessing__savgol*savgol___sg1': SavitzkyGolay(), 'regressor__preprocessing__savgol*savgol___sg2': SavitzkyGolay(), 'regressor__preprocessing__savgol*savgol___sg1__copy': True, 'regressor__preprocessing__savgol*savgol___sg1__delta': 1.0, 'regressor__preprocessing__savgol*savgol___sg1__deriv': 0, 'regressor__preprocessing__savgol*savgol___sg1__polyorder': 3, 'regressor__preprocessing__savgol*savgol___sg1__window_length': 11, 'regressor__preprocessing__savgol*savgol___sg2__copy': True, 'regressor__preprocessing__savgol*savgol___sg2__delta': 1.0, 'regressor__preprocessing__savgol*savgol___sg2__deriv': 0, 'regressor__preprocessing__savgol*savgol___sg2__polyorder': 3, 'regressor__preprocessing__savgol*savgol___sg2__window_length': 11, 'regressor__preprocessing__gaussian1*savgol__memory': None, 'regressor__preprocessing__gaussian1*savgol__steps': [('_g1', Gaussian(sigma=2)), ('_sg3', SavitzkyGolay())], 'regressor__preprocessing__gaussian1*savgol__verbose': False, 'regressor__preprocessing__gaussian1*savgol___g1': Gaussian(sigma=2), 'regressor__preprocessing__gaussian1*savgol___sg3': SavitzkyGolay(), 'regressor ...
#                 ('preprocessing',
#                  FeatureUnion(transformer_list=[('id', FunctionTransformer()),
#                                                 ('savgol', SavitzkyGolay()),
#                                                 ('gaussian1',
#                                                  Gaussian(sigma=2)),
#                                                 ('gaussian2',
#                                                  Gaussian(order=2)),
#                                                 ('haar', Wavelet()),
#                                                 ('savgol*savgol',
#                                                  Pipeline(steps=[('_sg1',
#                                                                   SavitzkyGolay()),
#                                                                  ('_sg2',
#                                                                   SavitzkyGolay())])),
#                                                 ('gaussian1*savgol',
#                                                  Pipeline(steps=...
#                               interaction_constraints=None, learning_rate=None,
#                               max_delta_step=None, max_depth=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, n_estimators=100,
#                               n_jobs=None, num_parallel_tree=None,
#                               predictor=None, random_state=None, reg_alpha=None,
#                               reg_lambda=None, scale_pos_weight=None,
#                               subsample=None, tree_method=None,
#                               validate_parameters=None, verbosity=None))]), 'transformer__clip': False, 'transformer__copy': True, 'transformer__feature_range': (0, 1), 'transformer': MinMaxScaler()}

# %% [markdown]
# ## GridSearch on param grid

# %%
from sklearn.model_selection import GridSearchCV

# Parameters of pipelines can be set using ‘__’ separated parameter names:
param_grid = {
    "regressor__XGB__max_depth": [5, 6, 7],
    "regressor__XGB__eta": [0.2, 0.3],
    "regressor__XGB__gamma": [0, 0.3],
}

search = GridSearchCV(x_estimator, 
                      param_grid, 
                      cv=3, 
                      n_jobs=2, 
                      verbose=3, 
                      scoring='neg_mean_squared_error')

search.fit(X_train, y_train)
print(search.best_params_)

Y_preds = search.predict(X_test)
print("MAE", mean_absolute_error(y_test, Y_preds))
print("MSE", mean_squared_error(y_test, Y_preds))
print("MAPE", mean_absolute_percentage_error(y_test, Y_preds))
print("R²", r2_score(y_test, Y_preds))
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# {'regressor__XGB__eta': 0.3, 'regressor__XGB__gamma': 0, 'regressor__XGB__max_depth': 5}
# MAE 1.3079682178359107
# MSE 3.4625930671667016
# MAPE 0.028900282120511277
# R² 0.6718040922482609

# %% [markdown]
# ## Same with KerasRegressor

# %%
from pinard.nirs_pipelines import FeatureAugmentation

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, SpatialDropout1D,BatchNormalization,Flatten, Dropout, Input

from scikeras.wrappers import KerasRegressor

from typing import Dict, Iterable, Any

# Create the keras model in the scikeras wrapper format (meta arg)
def keras_model(meta, sp_dropout, filter_1, filter_2, filter_3):
    print("META", meta)
    input_shape = meta["X_shape_"][1:]
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(SpatialDropout1D(sp_dropout))
    model.add(Conv1D (filters=filter_1, kernel_size=15, strides=5, activation='selu'))
    model.add(Dropout(0.2))
    model.add(Conv1D (filters=filter_2, kernel_size=21, strides=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv1D (filters=filter_3, kernel_size=5, strides=3, activation='elu'))
    model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dense(16, activation='sigmoid'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss = 'mean_squared_error', optimizer = 'adam')
    # model.summary()
    return model

# Create the KerasRegressor
k_regressor = KerasRegressor(model = keras_model,
                            epochs=400, 
                            sp_dropout=0.08,
                            filter_1=8,
                            filter_2=64,
                            filter_3=32,
                            fit__batch_size=50,
                            fit__validation_split=0.2,
                            verbose = 0)

# Declare the pipeline with a FeatureAugmentation (2D)
k_pipeline = Pipeline([
    ('scaler', MinMaxScaler()), 
    ('preprocessing', FeatureAugmentation(preprocessing)),
    ('KerasNN', k_regressor)
])

# Train and predict same as usual
k_estimator = TransformedTargetRegressor(regressor = k_pipeline, transformer = MinMaxScaler())
 
# Parameters of pipelines can be set using ‘__’ separated parameter names:
param_grid = {
    "regressor__KerasNN__model__sp_dropout": [0.05,0.25],
    "regressor__KerasNN__model__filter_1": [8,32,128],
    "regressor__KerasNN__model__filter_2": [8,32,128],
    "regressor__KerasNN__model__filter_3": [8,32,128]
}

search = GridSearchCV(k_estimator, 
                      param_grid, 
                      cv=3, 
                      verbose=2, 
                      scoring='neg_mean_squared_error')

search.fit(X_train, y_train)
print(search.best_params_)

Y_preds = search.predict(X_test)

print("MAE", mean_absolute_error(y_test, Y_preds))
print("MSE", mean_squared_error(y_test, Y_preds))
print("MAPE", mean_absolute_percentage_error(y_test, Y_preds))
print("R²", r2_score(y_test, Y_preds))
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  54.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  57.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.3s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026E9FFF5EE8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.8s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000026EA023D1F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  54.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  54.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  53.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  54.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.6s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  54.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  53.7s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.7s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.6s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  54.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  54.5s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  54.8s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.7s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  54.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  54.8s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.7s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.6s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  57.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.7s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.6s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  57.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  57.7s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.8s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  57.3s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  57.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  57.6s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.7s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  57.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  57.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=8, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  57.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.3s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.3s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.6s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.6s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  54.6s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.3s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  54.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  57.7s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.3s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  57.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.3s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=8, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.5s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.5s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  57.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.3s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  55.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.6s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  56.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  55.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  56.3s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=32, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  57.0s
# ...
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  59.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  57.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time=  58.5s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  58.7s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  58.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time=  57.4s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  58.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  57.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  58.3s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  58.6s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=32, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  59.1s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time=  59.0s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.05; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  59.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  59.2s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=8, regressor__KerasNN__model__sp_dropout=0.25; total time=  59.8s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.05; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=32, regressor__KerasNN__model__sp_dropout=0.25; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.05; total time=  59.9s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time=  59.7s
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (192, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# TRANSFORM
# ahahah (96, 2151, 9)
# [CV] END regressor__KerasNN__model__filter_1=128, regressor__KerasNN__model__filter_2=128, regressor__KerasNN__model__filter_3=128, regressor__KerasNN__model__sp_dropout=0.25; total time= 1.0min
# META {'target_type_': 'continuous', 'y_dtype_': dtype('float64'), 'y_ndim_': 1, 'X_dtype_': dtype('float32'), 'X_shape_': (288, 2151, 9), 'n_features_in_': 2151, 'target_encoder_': RegressorTargetEncoder(), 'n_outputs_': 1, 'n_outputs_expected_': 1, 'feature_encoder_': FunctionTransformer()}
# {'regressor__KerasNN__model__filter_1': 32, 'regressor__KerasNN__model__filter_2': 32, 'regressor__KerasNN__model__filter_3': 8, 'regressor__KerasNN__model__sp_dropout': 0.05}
# TRANSFORM
# ahahah (73, 2151, 9)
# MAE 1.2953786714109319
# MSE 2.80719698551102
# MAPE 0.02846499216211963
# R² 0.7339246786941656
